# %% [markdown]
# ### Regresión lineal múltiple

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../../dataset/insurance.csv')
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ## EDA
# * pairplot
# * heatmap
# * scatterplot
#
# Detectar que columnas afectan más a charges

# %%
sns.pairplot(df[['age', 'sex', 'bmi', 'children','smoker', 'region', 'charges']])

# %%
sns.scatterplot(df[['age', 'sex', 'bmi', 'children','smoker', 'region', 'charges']])
# Out:
# <Axes: >

# %%
df = sns.load_dataset('insurance')
df_cluster = df[['age', 'sex', 'bmi']].copy()
df_cluster['sex'] = df_cluster['sex'].map({
    'children': 1,
    'smoker': 2,
    'region': 3,
    'charges': 4
})
df_cluster.head(2)
